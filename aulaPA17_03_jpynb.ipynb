# %% [markdown]
# <a href="https://colab.research.google.com/github/authentickawaii67/PA1F-grupo-A/blob/main/aulaPA17_03_jpynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# operações aritiméticos
# fazer um programa mque calcula operações com 02 números

# entrada

a = int(input("digite um número: "))
b = int(input("digite um número: "))

# processamento

soma = a + b

# saida

print ("")
print("----------------------OPERADORES ARITIMÉTICOS----------------------")
print ("")
print ("----------------------------ADIÇÃO--------------------------------")
print ("")
print (f"o resultado da soma de {a} + {b} é igual a: {soma}.")
print ("")
print ("------------------------------------------------------------------")
# Out:
# digite um número: 2
# digite um número: 5
#
# ----------------------OPERADORES ARITIMÉTICOS----------------------
#
# ----------------------------ADIÇÃO--------------------------------
#
# o resultado da soma de 2 + 5 é igual a: 7.
#
# ------------------------------------------------------------------

# %%
# entrada

a = int(input("digite um número: "))
b = int(input("digite um número: "))

# processamento

menos = a-b

# saida

print ("")
print("----------------------OPERADORES ARITIMÉTICOS----------------------")
print ("")
print ("---------------------------SUBTRAÇÃO------------------------------")
print ("")
print (f"o resultado da subtração de {a} - {b} é igual a: {menos}.")
print ("")
print ("------------------------------------------------------------------")
# Out:
# digite um número: 7
# digite um número: 3
#
# ----------------------OPERADORES ARITIMÉTICOS----------------------
#
# ---------------------------SUBTRAÇÃO------------------------------
#
# o resultado da subtração de 7 - 3 é igual a: 4.
#
# ------------------------------------------------------------------

# %%
# entrada

a = int(input("digite um número: "))
b = int(input("digite um número: "))

# processamento

divis = a * b

# saida

print ("")
print("----------------------OPERADORES ARITIMÉTICOS----------------------")
print ("")
print ("--------------------------MULTIPLICAÇÃO---------------------------")
print ("")
print (f"o resultado da multiplicação de {a} * {b} é igual a: {divis}.")
print ("")
print ("------------------------------------------------------------------")
# Out:
# digite um número: 2
# digite um número: 5
#
# ----------------------OPERADORES ARITIMÉTICOS----------------------
#
# --------------------------MULTIPLICAÇÃO---------------------------
#
# o resultado da multiplicação de 2 * 5 é igual a: 10.
#
# ------------------------------------------------------------------

# %%
# entrada

a = int(input("digite um número: "))
b = int(input("digite um número: "))

# processamento

divis = a / b

# saida

print ("")
print("----------------------OPERADORES ARITIMÉTICOS----------------------")
print ("")
print ("-----------------------------DIVISÃO------------------------------")
print ("")
print (f"o resultado da divisão de {a} / {b} é igual a: {divis}.")
print ("")
print ("------------------------------------------------------------------")
# Out:
# digite um número: 8
# digite um número: 2
#
# ----------------------OPERADORES ARITIMÉTICOS----------------------
#
# -----------------------------DIVISÃO------------------------------
#
# o resultado da divisão de 8 / 2 é igual a: 4.0.
#
# ------------------------------------------------------------------

# %%
# OPeradores arítimeticos
#Fazer um porgarama que caucula operações com 02 numeros


#Entrada

a = int (input("Digite um numero "))
b = int (input(" Digite um numero "))

#Processamento

soma= a + b
sub= a - b
div= a / b
mult= a * b
div_int= a // b
resto= a % b
potencia= a ** b

#saída

print("")
print("-------------------------OPERADORES ARITIMETICOS-------------------------")
print("-------------------------------------------------------------------------")
print("-----------------------------------Soma----------------------------------")
print("")
print(f"O resultado de {a} mais {b} é igual a :{soma} ₍^. .^₎⟆")
print("")
print("-------------------------------------------------------------------------")
print("-----------------------------------Subtração----------------------------------")
print("")
print(f"O resultado de {a} menos {b} é igual a :{sub} ₍^. .^₎⟆")
print("")
print("-------------------------------------------------------------------------")
print("-----------------------------------Mult----------------------------------")
print("")
print(f"O resultado de {a} vezes {b} é igual a :{mult} ₍^. .^₎⟆")
print("")
print("-------------------------------------------------------------------------")
print("-----------------------------------Divisão----------------------------------")
print("")
print(f"O resultado de {a} sla oq é isso por {b} é igual a :{div_int} ₍^. .^₎⟆")
print("")
print("-------------------------------------------------------------------------")
print("-----------------------------------Resto----------------------------------")
print("")
print(f"O resultado de {a} dividido por {b} o resto é igual a :{resto} ₍^. .^₎⟆")
print("")
print("-------------------------------------------------------------------------")
print("-----------------------------------Potencia----------------------------------")
print("")
print(f"O resultado de {a} elevado por {b} o resto é igual a :{potencia} ₍^. .^₎⟆")
print("")
print("-------------------------------------------------------------------------")
# Out:
# Digite um numero 6
#  Digite um numero 7
#
# -------------------------OPERADORES ARITIMETICOS-------------------------
# -------------------------------------------------------------------------
# -----------------------------------Soma----------------------------------
#
# O resultado de 6 mais 7 é igual a :13 ₍^. .^₎⟆
#
# -------------------------------------------------------------------------
# -----------------------------------Subtração----------------------------------
#
# O resultado de 6 menos 7 é igual a :-1 ₍^. .^₎⟆
#
# -------------------------------------------------------------------------
# -----------------------------------Mult----------------------------------
#
# O resultado de 6 vezes 7 é igual a :42 ₍^. .^₎⟆
#
# -------------------------------------------------------------------------
# -----------------------------------Divisão----------------------------------
#
# O resultado de 6 sla oq é isso por 7 é igual a :0 ₍^. .^₎⟆
#
# ...

# %%
 # operadores relacionais

 # entrada

a = int(input("digite um número: "))
b = int(input("digite um número: "))

# processamento

# comparação

igual = a == b

# saida

print(igual)
# Out:
# digite um número: 1
# digite um número: 2
# False

# %%
# operadores relacionais

 # entrada

a = int(input("digite um número: "))
b = int(input("digite um número: "))

# processamento

# comparação

dif = a != b

# saida

print(dif)
# Out:
# digite um número: 1
# digite um número: 2
# True

# %%
# operadores relacionais

 # entrada

a = int(input("digite um número: "))
b = int(input("digite um número: "))

# processamento

# comparação

maior = a > b
menor = a < b
maiorigual = a >= b
menorigual = a <= b

# saida

print (maior)
print (menor)
print (maiorigual)
print (menorigual)
# Out:
# digite um número: 6
# digite um número: 7
# False
# True
# False
# True

# %%
# fazer um programa para converter a temperatura
# F = (C × 9/5) + 32

# entrada

c = int (input("digite o grau celsius: "))

# processamento

f = (c * 9/5) + 32

# saida

print(f"{c} graus celsius = {f} graus fahrenheit ")
# Out:
# digite o grau celsius 6
# 6 graus celsius = 42.8 graus fahrenheit

# %%
# fazer um programa que converte km em metros

# entrada

km = int (input("digite a quantidade de km:"))

# processamento

m = km * 1000

# saida

print (f"{km}km = {m}m")
# Out:
# digite a quantidade de km:6
# 6km = 6000m

# %%
#fazer um programa que converte horas em minutos
#entrada
h= int(input("digite a quantidade de horas: "))

#processaneto
m= h*60

#saida
print(f"{h}h = {m}m")
# Out:
# digite a quantidade de horas: 7
# 7h = 420m
